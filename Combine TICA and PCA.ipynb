# %%
import pyemma.coordinates as coords
import mdtraj as md
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools

from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist, pdist
from sklearn.metrics import pairwise_distances_argmin
import sklearn

from math import sqrt
import sys
import os

from datetime import date
from subprocess import call

# %%
trajfile = 'C:\\Users\\data\\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\\sarscov2-10880334-no-water-no-ion-glueCA\\Mpro_traj(7).dcd'
topfile = 'C:\\Users\\data\\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\\sarscov2-10880334-no-water-no-ion-glueCA\\Mpro.pdb'
#trajfile = 'C:\\Users\\data\\Crystals.xtc'
#topfile = 'C:\\Users\\data\\REFprot.pdb'
project_dir = os.path.dirname(os.getcwd())

# %%
traj = md.load(trajfile[:],  stride = 1, top = topfile)
feat = coords.featurizer(topfile)
# just use all xyz-coordinates
feat.add_all()

# %%
inp = coords.source(trajfile, feat)

# %% [markdown]
# # TICA

# %%
 def optimal_number_of_clusters(wcss):
    # Function to define the optimal number of clusters
    x1, y1 = 1, wcss[0]
    x2, y2 = 100, wcss[len(wcss)-1]

    distances = []
    for i in range(len(wcss)):
        x0 = i+2
        y0 = wcss[i]
        numerator = abs((y2-y1)*x0 - (x2-x1)*y0 + x2*y1 - y2*x1)
        denominator = sqrt((y2 - y1)**2 + (x2 - x1)**2)
        distances.append(numerator/denominator)
    
    return distances.index(max(distances)) + 2

# %%
lag=100
tica_obj = coords.tica(inp, lag=lag, dim=2, kinetic_map=True)
# here we get the data that has been projected onto the first 2 IC's. It's a list, because we could generally
# have a list of trajectories, so we just get the first element.
Y = tica_obj.get_output()[0]
tica_components = tica_obj.fit_transform(Y) * -1
tica_components_df = pd.DataFrame(tica_components)
tica_eigenvalues = tica_obj.eigenvalues
pc_id = list(range(len(tica_eigenvalues)))
tica_eigen_df = pd.DataFrame({"pc_id": pc_id, "eig_cum": tica_obj.cumvar, "eig_values": tica_eigenvalues})
print(tica_eigen_df)
n_tica = tica_eigen_df[tica_eigen_df['eig_cum'] <= 2]
n_tica = n_tica.shape[0]
tica_components_df = pd.DataFrame(tica_components)
X = tica_components_df.iloc[:,:n_tica]
X.shape
inertias = []
K = range(1, 100)

for k in K:
    model = KMeans(n_clusters = k, random_state = 100)
    model.fit(X)
    inertias.append(model.inertia_)
    
n = optimal_number_of_clusters(inertias)    
print(n)
plt.figure()
plt.scatter(tica_components[:, 0], tica_components[:,1], marker = 'x', c = traj.time)
plt.xlabel('IC1')
plt.ylabel('IC2')
cbar = plt.colorbar()
cbar.set_label('Time [ps]')
km_ = KMeans(n_clusters = n)
km_ = km_.fit(X)

plt.show()
# Out:
#    pc_id  eig_cum  eig_values
# 0      0      0.5         1.0
# 1      1      1.0        -1.0
# C:\Users\Mondello\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# 13

# %%
OPTIONAL = True
execution = date.today().strftime('%Y-%m-%d')

closest = pairwise_distances_argmin(km_.cluster_centers_, X)
representatives = []

try:
    os.makedirs(os.path.join(project_dir + "\\data\\" + "clusters", execution))
except OSError:
    print ("Creation of the directory %s failed" % execution)
else:
    print ("Successfully created the directory %s " % execution)

for i in enumerate(closest):
    traj_index = int((i[1]-1) / traj.n_frames)
    frame_index = i[1]-(traj_index * traj.n_frames)

    n_cluster = str(i[0])
    
    representatives.append([traj_index, frame_index, i[1]])
    print(f"Closest conformation inside cluster {n_cluster} can be found in trajectory {traj_index} frame {frame_index}, (index {i[1]})")

    if OPTIONAL:   
        convert_command = f"mdconvert {trajfile} -t {topfile} -o {project_dir}\\data\\clusters\\{execution}\\TICA_in_cluster_{n_cluster}_{frame_index}.pdb"        
        print(convert_command)

        call(convert_command, shell = True)
# Out:
# Creation of the directory 2021-09-14 failed
# Closest conformation inside cluster 0 can be found in trajectory 0 frame 128, (index 128)
# mdconvert C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro_traj(7).dcd -t C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro.pdb -o C:\Users\Mondello\data\clusters\2021-09-14\TICA_in_cluster_0_128.pdb
# Closest conformation inside cluster 1 can be found in trajectory 0 frame 0, (index 0)
# mdconvert C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro_traj(7).dcd -t C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro.pdb -o C:\Users\Mondello\data\clusters\2021-09-14\TICA_in_cluster_1_0.pdb
# Closest conformation inside cluster 2 can be found in trajectory 0 frame 82, (index 82)
# mdconvert C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro_traj(7).dcd -t C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro.pdb -o C:\Users\Mondello\data\clusters\2021-09-14\TICA_in_cluster_2_82.pdb
# Closest conformation inside cluster 3 can be found in trajectory 0 frame 117, (index 117)
# mdconvert C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro_traj(7).dcd -t C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro.pdb -o C:\Users\Mondello\data\clusters\2021-09-14\TICA_in_cluster_3_117.pdb
# Closest conformation inside cluster 4 can be found in trajectory 0 frame 41, (index 41)
# mdconvert C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro_traj(7).dcd -t C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro.pdb -o C:\Users\Mondello\data\clusters\2021-09-14\TICA_in_cluster_4_41.pdb
# Closest conformation inside cluster 5 can be found in trajectory 0 frame 106, (index 106)
# mdconvert C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro_traj(7).dcd -t C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro.pdb -o C:\Users\Mondello\data\clusters\2021-09-14\TICA_in_cluster_5_106.pdb
# Closest conformation inside cluster 6 can be found in trajectory 0 frame 47, (index 47)
# mdconvert C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro_traj(7).dcd -t C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro.pdb -o C:\Users\Mondello\data\clusters\2021-09-14\TICA_in_cluster_6_47.pdb
# Closest conformation inside cluster 7 can be found in trajectory 0 frame 147, (index 147)
# mdconvert C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro_traj(7).dcd -t C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro.pdb -o C:\Users\Mondello\data\clusters\2021-09-14\TICA_in_cluster_7_147.pdb
# Closest conformation inside cluster 8 can be found in trajectory 0 frame 141, (index 141)
# mdconvert C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro_traj(7).dcd -t C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro.pdb -o C:\Users\Mondello\data\clusters\2021-09-14\TICA_in_cluster_8_141.pdb
# Closest conformation inside cluster 9 can be found in trajectory 0 frame 65, (index 65)
# mdconvert C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro_traj(7).dcd -t C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro.pdb -o C:\Users\Mondello\data\clusters\2021-09-14\TICA_in_cluster_9_65.pdb
# Closest conformation inside cluster 10 can be found in trajectory 0 frame 91, (index 91)
# mdconvert C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro_traj(7).dcd -t C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro.pdb -o C:\Users\Mondello\data\clusters\2021-09-14\TICA_in_cluster_10_91.pdb
# Closest conformation inside cluster 11 can be found in trajectory 0 frame 169, (index 169)
# mdconvert C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro_traj(7).dcd -t C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro.pdb -o C:\Users\Mondello\data\clusters\2021-09-14\TICA_in_cluster_11_169.pdb
# Closest conformation inside cluster 12 can be found in trajectory 0 frame 2, (index 2)
# mdconvert C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro_traj(7).dcd -t C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro.pdb -o C:\Users\Mondello\data\clusters\2021-09-14\TICA_in_cluster_12_2.pdb

# %%
import numpy as np
# %pylab inline
subplot2grid((2,1),(0,0))
plot(Y[:,0])
ylabel('ind. comp. 1')
subplot2grid((2,1),(1,0))
plot(Y[:,1])
ylabel('ind. comp. 2')
xlabel('time (1000 ns)')
Text(0.5,0,'time (1000 ns)')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\Mondello\anaconda3\lib\site-packages\IPython\core\magics\pylab.py:159: UserWarning: pylab import has clobbered these variables: ['sqrt']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +
# Text(0.5, 0, 'time (1000 ns)')

# %%
print('Mean values: ', np.mean(Y, axis=0))
print('Variances:   ', np.var(Y, axis=0))
# Out:
# Mean values:  [8.3446505e-10 1.1026859e-09]
# Variances:    [0.9999997  0.99999994]

# %%
# histogram data
z,x,y = np.histogram2d(Y[:,0],Y[:,1])
# compute free energies
F = -np.log(z)
# contour plot
extent = [x[0], x[-1], y[0], y[-1]]
contourf(F.T,50,cmap=plt.cm.hot, extent=extent)
# Out:
# <ipython-input-10-6dbc62f36095>:4: RuntimeWarning: divide by zero encountered in log
#   F = -np.log(z)

# %%
cl = coords.cluster_kmeans(data=Y, k=100, stride=1)
# for later use we save the discrete trajectories and cluster center coordinates:
dtrajs = cl.dtrajs
cc_x = cl.clustercenters[:,0]
cc_y = cl.clustercenters[:,1]
# Out:
# initialize kmeans++ centers:   0%|                                                             | 0/100 [00:00<…
# kmeans iterations:   0%|                                                                        | 0/10 [00:00<…

# %%
contourf(F.T,cmap=plt.cm.hot, extent=extent)
plot(cc_x,cc_y, linewidth=0, marker='o')

# %% [markdown]
# # PCA

# %%
pca_obj = coords.pca(inp, dim=2)
Ypca = pca_obj.get_output()[0]
subplot2grid((2,1),(0,0))
plot(Ypca[:,0])
ylabel('principal comp. 1')
subplot2grid((2,1),(1,0))
plot(Ypca[:,1])
ylabel('principal comp. 2')
xlabel('time (10 ns)')
plt.figure()
plt.scatter(Ypca[:, 0], Ypca[:,1], marker = 'x', c = traj.time)
plt.xlabel('PC1')
plt.ylabel('PC2')
cbar = plt.colorbar()
cbar.set_label('Time [ps]')

plt.show()

# %%
def _to_free_energy(z, minener_zero=False):

    pi = z / float(z.sum())
    free_energy = np.inf * np.ones(shape=z.shape)
    nonzero = pi.nonzero()
    free_energy[nonzero] = -np.log(pi[nonzero])

    if minener_zero:
        free_energy[nonzero] -= np.min(free_energy[nonzero])
    return free_energy

def get_histogram(
        xall, yall, nbins = 100,
        weights = None, avoid_zero_count = False):
  
    z, xedge, yedge = np.histogram2d(
        xall, yall, bins = nbins, weights = weights)
    
    x = 0.5 * (xedge[:-1] + xedge[1:])
    y = 0.5 * (yedge[:-1] + yedge[1:])

    if avoid_zero_count:
        z = np.maximum(z, np.min(z[z.nonzero()]))
    return x, y, z.T

# %%
from sklearn.decomposition import PCA

pca_sklearn = PCA(random_state = 100)
pca_components = pca_sklearn.fit_transform(Ypca) * -1
plt.figure()
plt.scatter(pca_components[:, 0], pca_components[:,1], marker = 'x', c = traj.time)
plt.xlabel('PC1')
plt.ylabel('PC2')
cbar = plt.colorbar()
cbar.set_label('Time [ps]')
x, y, z = get_histogram(pca_components[:,0], pca_components[:,1])

plt.show()

# %%
kT = 1.0
f = _to_free_energy(z, minener_zero =  True) * kT

# %%
import matplotlib.pyplot as _plt

fig, ax = _plt.subplots()
mappable = ax.contourf(
    x, y, f, 100, norm = None,
    vmin = None, vmax = None, cmap = 'nipy_spectral',
    levels = None)

misc = dict(mappable = mappable)
cbar_ = fig.colorbar(
    mappable, ax = None, orientation = 'vertical')
cbar_.set_label('free energy / kT')

plt.show()

# %%
pca_eigenvalues = pca_sklearn.explained_variance_ratio_
pc_id = list(range(len(pca_eigenvalues)))
print(pc_id)
pca_eigen_df = pd.DataFrame({"pc_id": pc_id, "eig_cum": np.cumsum(pca_eigenvalues), "eig_values": pca_eigenvalues})
pca_eigen_df.head()
# Out:
# [0, 1]
#    pc_id  eig_cum  eig_values
# 0      0  0.60714    0.607140
# 1      1  1.00000    0.392859

# %%
plt.plot(np.cumsum(pca_eigenvalues))
plt.xlabel("Principal Components")
plt.ylabel('Cumulative Explained Variance')
plt.show()

# %%
plt.scatter(np.arange(len(pca_eigenvalues)), pca_eigenvalues)
plt.xlabel("Principal Components")
plt.ylabel("Explained Variance (Eigenvalue)")
plt.show()

# %%
n_pca = pca_eigen_df[pca_eigen_df['eig_cum'] <= 2]
n_pca = n_pca.shape[0]

# %%
pca_components_df = pd.DataFrame(pca_components)

# %%
X = pca_components_df.iloc[:,:n_pca]
X.shape
# Out:
# (1000, 2)

# %%
inertias = []
K = range(1, 100)

for k in K:
    model = KMeans(n_clusters = k, random_state = 100)
    model.fit(X)
    inertias.append(model.inertia_)
# Out:
# C:\Users\Mondello\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(

# %%
plt.plot(K, inertias, '-o', color='black')
plt.xlabel('# of clusters, k')
plt.ylabel('inertia')
plt.title('Elbow Method For Optimal k')

plt.show()

# %%
n = optimal_number_of_clusters(inertias)
print("Optimal number of clusters: ", n)
# Out:
# Optimal number of clusters:  9

# %%
km = KMeans(n_clusters = n)
km = km.fit(X)

# %%
OPTIONAL = True
execution = date.today().strftime('%Y-%m-%d')

closest = pairwise_distances_argmin(km.cluster_centers_, X)
representatives = []

try:
    os.makedirs(os.path.join(project_dir + "\\data\\" + "clusters", execution))
except OSError:
    print ("Creation of the directory %s failed" % execution)
else:
    print ("Successfully created the directory %s " % execution)

for i in enumerate(closest):
    traj_index = int((i[1]-1) / traj.n_frames)
    frame_index = i[1]-(traj_index * traj.n_frames)

    n_cluster = str(i[0])
    
    representatives.append([traj_index, frame_index, i[1]])
    print(f"Closest conformation inside cluster {n_cluster} can be found in trajectory {traj_index} frame {frame_index}, (index {i[1]})")

    if OPTIONAL:   
        convert_command = f"mdconvert {trajfile} -t {topfile} -o {project_dir}\\data\\clusters\\{execution}\\PCA_in_cluster_{n_cluster}_{frame_index}.pdb"        
        print(convert_command)

        call(convert_command, shell = True)
# Out:
# Creation of the directory 2021-09-14 failed
# Closest conformation inside cluster 0 can be found in trajectory 0 frame 712, (index 712)
# mdconvert C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro_traj(7).dcd -t C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro.pdb -o C:\Users\Mondello\data\clusters\2021-09-14\PCA_in_cluster_0_712.pdb
# Closest conformation inside cluster 1 can be found in trajectory 0 frame 246, (index 246)
# mdconvert C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro_traj(7).dcd -t C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro.pdb -o C:\Users\Mondello\data\clusters\2021-09-14\PCA_in_cluster_1_246.pdb
# Closest conformation inside cluster 2 can be found in trajectory 0 frame 424, (index 424)
# mdconvert C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro_traj(7).dcd -t C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro.pdb -o C:\Users\Mondello\data\clusters\2021-09-14\PCA_in_cluster_2_424.pdb
# Closest conformation inside cluster 3 can be found in trajectory 0 frame 744, (index 744)
# mdconvert C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro_traj(7).dcd -t C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro.pdb -o C:\Users\Mondello\data\clusters\2021-09-14\PCA_in_cluster_3_744.pdb
# Closest conformation inside cluster 4 can be found in trajectory 0 frame 138, (index 138)
# mdconvert C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro_traj(7).dcd -t C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro.pdb -o C:\Users\Mondello\data\clusters\2021-09-14\PCA_in_cluster_4_138.pdb
# Closest conformation inside cluster 5 can be found in trajectory 0 frame 796, (index 796)
# mdconvert C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro_traj(7).dcd -t C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro.pdb -o C:\Users\Mondello\data\clusters\2021-09-14\PCA_in_cluster_5_796.pdb
# Closest conformation inside cluster 6 can be found in trajectory 0 frame 955, (index 955)
# mdconvert C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro_traj(7).dcd -t C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro.pdb -o C:\Users\Mondello\data\clusters\2021-09-14\PCA_in_cluster_6_955.pdb
# Closest conformation inside cluster 7 can be found in trajectory 0 frame 449, (index 449)
# mdconvert C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro_traj(7).dcd -t C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro.pdb -o C:\Users\Mondello\data\clusters\2021-09-14\PCA_in_cluster_7_449.pdb
# Closest conformation inside cluster 8 can be found in trajectory 0 frame 333, (index 333)
# mdconvert C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro_traj(7).dcd -t C:\Users\data\DESRES-Trajectory_sarscov2-10880334-no-water-no-ion-glueCA\sarscov2-10880334-no-water-no-ion-glueCA\Mpro.pdb -o C:\Users\Mondello\data\clusters\2021-09-14\PCA_in_cluster_8_333.pdb

# %%
plt.scatter(pca_components[:,0], pca_components[:,1], c="lightgrey")
plt.xlabel("PC1")
plt.ylabel("PC2")

[plt.scatter(pca_components[yr[2],0], pca_components[yr[2],1], c="red") for yr in representatives]

plt.legend(["PCA", "cluster representative"], loc='upper center', bbox_to_anchor=(0.5, 1.13), fancybox=True, shadow=True, ncol=5)

plt.show()

# %%
cc = km_.cluster_centers_
print(cc)

#plotting all elements
#plt.scatter(pca_components_df.iloc[:, 0], pca_components_df.iloc[:, 1], c = "lightgrey")
plt.scatter(tica_components[:, 0], tica_components[:,1],c="lightgrey")
plt.xlabel("IC1")
plt.ylabel("IC2")

# plotting cluster centers
plt.scatter(cc[:, 0], cc[:, 1], c="green") 
plt.colorbar()
plt.show()
# Out:
# [[ 1.1404847e+00 -1.4692602e+00]
#  [-2.0794480e-01  6.6314512e-01]
#  [-9.5657688e-01 -7.2613083e-02]
#  [ 6.6333807e-01  8.6021453e-01]
#  [-1.6038876e+00 -9.6533018e-01]
#  [ 8.6371148e-01 -1.8338127e-01]
#  [-5.6860518e-01  1.7586040e+00]
#  [-5.6860518e-01 -1.7586040e+00]
#  [-1.6038877e+00  9.6533018e-01]
#  [ 1.2537290e+00  1.5873021e+00]
#  [-4.1513938e-02  8.8981222e-10]
#  [ 2.0385455e-02 -7.8786510e-01]
#  [ 1.8134406e+00  1.6987324e-09]]
